# %%
# CNN MNIST
import numpy as np
import tensorflow as tf
import random

mnist = tf.keras.datasets.mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_test = x_test/255
x_train = x_train/255
x_train = x_train.reshape(x_train.shape[0], 28, 28, 1) # black and white
x_test = x_test.reshape(x_test.shape[0], 28, 28, 1)

# one hot
y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)

# hyper parameters
learning_rate = 0.001
training_epochs = 12
batch_size = 128

tf.model = tf.keras.Sequential()
# Layer 1
tf.model.add(tf.keras.layers.Conv2D(filters=16, kernel_size=(3,3), input_shape=(28,28,1), activation='relu'))
tf.model.add(tf.keras.layers.MaxPooling2D(pool_size=(2,2)))

# Layer 2
tf.model.add(tf.keras.layers.Conv2D(filters=32, kernel_size=(3,3), activation='relu'))
tf.model.add(tf.keras.layers.MaxPooling2D(pool_size=(2,2)))

# Layer 3 => FC
tf.model.add(tf.keras.layers.Flatten())
tf.model.add(tf.keras.layers.Dense(units=10, kernel_initializer='glorot_normal', activation='softmax'))

tf.model.compile(loss='categorical_crossentropy', optimizer=tf.keras.optimizers.Adam(lr=learning_rate), metrics=['accuracy'])
tf.model.summary()

#training
tf.model.fit(x_train,y_train,epochs=training_epochs, batch_size=batch_size)

# prediction
y_predicted = tf.model.predict(x_test)
for x in range(10):
  random_index = random.randint(0, x_test.shape[0]-1)
  print("index: ", random_index,
        "actual y: ", np.argmax(y_test[random_index]),
        "predicted y: ", np.argmax(y_predicted[random_index]))
  evaluation = tf.model.evaluate(x_test, y_test)
  print("loss: ", evaluation[0])
  print("accuracy: ", evaluation[1])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 16)        160
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 16)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 32)        4640
#
#  max_pooling2d_1 (MaxPooling  (None, 5, 5, 32)         0
#  2D)
#
#  flatten (Flatten)           (None, 800)               0
#
#  dense (Dense)               (None, 10)                8010
#
# =================================================================
# Total params: 12,810
# Trainable params: 12,810
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/12
# 469/469 [==============================] - 24s 49ms/step - loss: 0.3815 - accuracy: 0.8894
# Epoch 2/12
# 469/469 [==============================] - 25s 53ms/step - loss: 0.1042 - accuracy: 0.9692
# Epoch 3/12
# 469/469 [==============================] - 23s 50ms/step - loss: 0.0780 - accuracy: 0.9764
# Epoch 4/12
# 469/469 [==============================] - 24s 50ms/step - loss: 0.0642 - accuracy: 0.9809
# Epoch 5/12
# 469/469 [==============================] - 24s 51ms/step - loss: 0.0563 - accuracy: 0.9830
# Epoch 6/12
# 469/469 [==============================] - 25s 53ms/step - loss: 0.0498 - accuracy: 0.9846
# Epoch 7/12
# 469/469 [==============================] - 25s 54ms/step - loss: 0.0438 - accuracy: 0.9868
# Epoch 8/12
# 469/469 [==============================] - 25s 53ms/step - loss: 0.0407 - accuracy: 0.9872
# Epoch 9/12
# 469/469 [==============================] - 25s 53ms/step - loss: 0.0359 - accuracy: 0.9893
# Epoch 10/12
# 469/469 [==============================] - 25s 54ms/step - loss: 0.0340 - accuracy: 0.9893
# Epoch 11/12
# 469/469 [==============================] - 25s 53ms/step - loss: 0.0304 - accuracy: 0.9908
# Epoch 12/12
# 469/469 [==============================] - 25s 53ms/step - loss: 0.0288 - accuracy: 0.9911
# index:  6836 actual y:  2 predicted y:  2
# 313/313 [==============================] - 3s 7ms/step - loss: 0.0346 - accuracy: 0.9886
# loss:  0.034617193043231964
# accuracy:  0.9886000156402588
# index:  9882 actual y:  3 predicted y:  3
# 313/313 [==============================] - 2s 7ms/step - loss: 0.0346 - accuracy: 0.9886
# loss:  0.034617193043231964
# accuracy:  0.9886000156402588
# index:  6278 actual y:  1 predicted y:  1
# 313/313 [==============================] - 2s 7ms/step - loss: 0.0346 - accuracy: 0.9886
# loss:  0.034617193043231964
# accuracy:  0.9886000156402588
# index:  2706 actual y:  1 predicted y:  1
# 313/313 [==============================] - 2s 7ms/step - loss: 0.0346 - accuracy: 0.9886
# loss:  0.034617193043231964
# accuracy:  0.9886000156402588
# index:  6899 actual y:  5 predicted y:  5
# 313/313 [==============================] - 2s 7ms/step - loss: 0.0346 - accuracy: 0.9886
# loss:  0.034617193043231964
# accuracy:  0.9886000156402588
# index:  9242 actual y:  7 predicted y:  7
# 313/313 [==============================] - 2s 7ms/step - loss: 0.0346 - accuracy: 0.9886
# loss:  0.034617193043231964
# accuracy:  0.9886000156402588
# index:  8836 actual y:  4 predicted y:  4
# 313/313 [==============================] - 2s 7ms/step - loss: 0.0346 - accuracy: 0.9886
# loss:  0.034617193043231964
# accuracy:  0.9886000156402588
# index:  1397 actual y:  1 predicted y:  1
# 313/313 [==============================] - 2s 8ms/step - loss: 0.0346 - accuracy: 0.9886
# loss:  0.034617193043231964
# accuracy:  0.9886000156402588
# index:  5462 actual y:  8 predicted y:  8
# 313/313 [==============================] - 2s 7ms/step - loss: 0.0346 - accuracy: 0.9886
# loss:  0.034617193043231964
# accuracy:  0.9886000156402588
# index:  2595 actual y:  7 predicted y:  7
# 313/313 [==============================] - 2s 7ms/step - loss: 0.0346 - accuracy: 0.9886
# loss:  0.034617193043231964
# accuracy:  0.9886000156402588
